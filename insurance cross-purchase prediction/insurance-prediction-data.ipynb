# %% [markdown]
# # End-to-end ML miniproject
#
# We will attempt to solve a possible data science problem: https://www.kaggle.com/datasets/anmolkumar/health-insurance-cross-sell-prediction. We will go through a step-by-step process:
#
# - Establishing the problem statement and finding a suitable metric
# - Exploratory analysis of a dataset
# - Develop a data processing pipeline in pandas
# - Trying different ML tabular algorithms such as random forests, gradient boosting
# - Hyperparameter tuning and optimizing for our chosen metric on the cross-validation set
# - Present the results to the wider community (as the problem treated here is somewhat artificial and uninteresting in itself this step will be skipped)

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/health-insurance-cross-sell-prediction/sample_submission.csv
# /kaggle/input/health-insurance-cross-sell-prediction/train.csv
# /kaggle/input/health-insurance-cross-sell-prediction/test.csv

# %%
train_set = pd.read_csv(os.path.join(dirname, 'train.csv'))
test_set = pd.read_csv(os.path.join(dirname, 'test.csv'))

# %% [markdown]
# ## Problem statement
# Our interest in the dataset is to predict the probability for a customer to buy car insurance, given some details about them. This will amount to a classification task.
#
# Because the target feature is imbalanced, we need to be careful with our choice of metric, because accuracy by itself will not be a good performance indicator. The standard metrics to use are ROC AUC score (which is independent of the decision threshold) and F1 score (which can be improved by tweaking the threshold from 0.5 to something lower).

# %% [markdown]
# ## EDA and data cleaning

# %%
train_set.head()
# Out:
#    id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0   1    Male   44                1         28.0                   0
# 1   2    Male   76                1          3.0                   0
# 2   3    Male   47                1         28.0                   0
# 3   4    Male   21                1         11.0                   1
# 4   5  Female   29                1         41.0                   1
#
#   Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  \
# 0   > 2 Years            Yes         40454.0                  26.0      217
# 1    1-2 Year             No         33536.0                  26.0      183
# 2   > 2 Years            Yes         38294.0                  26.0       27
# 3    < 1 Year             No         28619.0                 152.0      203
# 4    < 1 Year             No         27496.0                 152.0       39
#
#    Response
# 0         1
# 1         0
# 2         1
# 3         0
# 4         0

# %% [markdown]
# Gender, Vehicle_Age and Vehicle_Damage are categorical features taking few values so we will be able to do a one hot encoding. Another possibility which i do not pursue here is to encode age with an appropiate ordinal encoder (0 for 1 year, 1 for 1-2 years, etc)

# %%
train_set.describe()
# Out:
#                   id            Age  Driving_License    Region_Code  \
# count  381109.000000  381109.000000    381109.000000  381109.000000
# mean   190555.000000      38.822584         0.997869      26.388807
# std    110016.836208      15.511611         0.046110      13.229888
# min         1.000000      20.000000         0.000000       0.000000
# 25%     95278.000000      25.000000         1.000000      15.000000
# 50%    190555.000000      36.000000         1.000000      28.000000
# 75%    285832.000000      49.000000         1.000000      35.000000
# max    381109.000000      85.000000         1.000000      52.000000
#
#        Previously_Insured  Annual_Premium  Policy_Sales_Channel  \
# count       381109.000000   381109.000000         381109.000000
# mean             0.458210    30564.389581            112.034295
# std              0.498251    17213.155057             54.203995
# min              0.000000     2630.000000              1.000000
# 25%              0.000000    24405.000000             29.000000
# 50%              0.000000    31669.000000            133.000000
# 75%              1.000000    39400.000000            152.000000
# max              1.000000   540165.000000            163.000000
#
#              Vintage       Response
# count  381109.000000  381109.000000
# mean      154.347397       0.122563
# std        83.671304       0.327936
# min        10.000000       0.000000
# 25%        82.000000       0.000000
# 50%       154.000000       0.000000
# 75%       227.000000       0.000000
# max       299.000000       1.000000

# %% [markdown]
# `id` is not relevant so we will drop it. We can further notice that the Driving_Licence mean is ~1, so we can happily conclude that the firm probably never provided car insurance to someone without a driver's license. We can the remove instances without driver's licenses (likely errors in our database).

# %%
#imputer is not needed
train_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 381109 entries, 0 to 381108
# Data columns (total 12 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    381109 non-null  int64
#  1   Gender                381109 non-null  object
#  2   Age                   381109 non-null  int64
#  3   Driving_License       381109 non-null  int64
#  4   Region_Code           381109 non-null  float64
#  5   Previously_Insured    381109 non-null  int64
#  6   Vehicle_Age           381109 non-null  object
#  7   Vehicle_Damage        381109 non-null  object
#  8   Annual_Premium        381109 non-null  float64
#  9   Policy_Sales_Channel  381109 non-null  float64
#  10  Vintage               381109 non-null  int64
#  11  Response              381109 non-null  int64
# dtypes: float64(3), int64(6), object(3)
# memory usage: 34.9+ MB

# %%
def cleaning(train_set):
    train = train_set.drop('id', axis=1)
    return train

train_copy = cleaning(train_set)
y = train_copy.Response
X = train_copy.drop('Response', axis=1)

# %% [markdown]
# ## Data Preprocessing

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OrdinalEncoder, MinMaxScaler


num_att = ['Age', 'Driving_License', 'Region_Code', 'Previously_Insured', 
           'Annual_Premium', 'Policy_Sales_channel', 'Vintage']
cat_att = ['Gender', 'Vehicle_Age', 'Vehicle_Damage']

cat_encoder = ColumnTransformer([("cat", OrdinalEncoder(), cat_att)], 
                                remainder='passthrough')

engineering_pipeline = Pipeline([
    ("cat_encoder", cat_encoder),
    ("scaler", MinMaxScaler())
])

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import f1_score, roc_auc_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV

# for fairness we will fit the engineering pipeline only on the training set
_X_train, _X_val, y_train, y_val = train_test_split(X, y, random_state=123)
X_train = engineering_pipeline.fit_transform(_X_train)
X_val = engineering_pipeline.transform(_X_val)

# %% [markdown]
# We will apply standard oversampling techniques using the SMOTE library.

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE(random_state=3301)

Xt_smoted, yt_smoted = smote.fit_resample(X_train, y_train)

print(Xt_smoted.shape)
# Out:
# (501466, 10)

# %% [markdown]
# ## RFC random search grid

# %%
RandomForestClassifier()
params = {
    'max_depth': range(5,30),
    'min_samples_leaf': [1,2,3,5,10,20,30,50],
    'max_leaf_nodes': [10,100,1000,10000],
    
    
    'n_jobs': [-1],
    'random_state': [3301]
}

rfc = RandomizedSearchCV(RandomForestClassifier(), params,
                        cv=3, 
                        return_train_score=True,
                        scoring='roc_auc',
                        n_iter=15,
                        verbose=2,
                        random_state=3301)

# %%
## XGBoost grid

# %%
from xgboost import XGBClassifier

param_xgb = {
 'max_depth': range(3,10,2),
 'min_child_weight': range(1,6,2), 
 'gamma': [0, 0.5, 1, 10]
}

gsearch1 = GridSearchCV(estimator = XGBClassifier( learning_rate =0.05, 
                                                  n_estimators=500, 
                                                  max_depth=5,
                                                  min_child_weight=1, 
                                                  gamma=0, 
                                                  subsample=0.8, 
                                                  colsample_bytree=0.8,
                                                  objective= 'binary:logistic', 
                                                  nthread=4, 
                                                  scale_pos_weight=1, 
                                                  seed=3301), 
                        param_grid=param_xgb, 
                        #n_iter=20,
                        scoring='roc_auc',
                        n_jobs=4,
                        iid=False, 
                        cv=3,
                        verbose=1)

gsearch1.fit(X_train, y_train,
             eval_set=[(X_val, y_val)],
             eval_metric='auc',
             early_stopping_rounds=30,
             verbose=False)
print(gsearch1.best_params_, gsearch1.best_score_)
# Out:
# Fitting 3 folds for each of 48 candidates, totalling 144 fits
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed: 46.8min
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [Parallel(n_jobs=4)]: Done 144 out of 144 | elapsed: 157.9min finished
# /opt/conda/lib/python3.7/site-packages/sklearn/model_selection/_search.py:849: FutureWarning: The parameter 'iid' is deprecated in 0.22 and will be removed in 0.24.
#   "removed in 0.24.", FutureWarning
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# {'gamma': 0, 'max_depth': 5, 'min_child_weight': 1} 0.857535794853251

# %% [markdown]
# Below: I found these parameters to work decently.

# %%
from xgboost import XGBClassifier

#randomsearch results
gsparams = {'subsample': 0.72, 
            'min_child_weight': 3, 'max_depth': 5, 'gamma': 3, 
            'colsample_bytree': 0.76} 
0.8577270969019691

#gridsearch obtained when searching only for min_child_depth and max_depth
gsparams = {'subsample': 0.8, 
            'min_child_weight': 5, 'max_depth': 5, 'gamma': 0, 
            'colsample_bytree': 0.8}

estimator = XGBClassifier( learning_rate =0.05, 
                          n_estimators=500, 
                          max_depth=5,
                          min_child_weight=5, 
                          gamma=0, 
                          subsample=0.8, 
                          colsample_bytree=0.8,
                          objective= 'binary:logistic', 
                          nthread=4, 
                          scale_pos_weight=1, 
                          seed=27)

estimator.fit(X_train, y_train,
             eval_set=[(X_val, y_val)],
             eval_metric='auc',
             early_stopping_rounds=30)
# Out:
# [0]	validation_0-auc:0.82267
# [1]	validation_0-auc:0.82389
# [2]	validation_0-auc:0.83751
# [3]	validation_0-auc:0.84132
# [4]	validation_0-auc:0.84354
# [5]	validation_0-auc:0.84471
# [6]	validation_0-auc:0.84841
# [7]	validation_0-auc:0.84801
# [8]	validation_0-auc:0.84786
# [9]	validation_0-auc:0.84820
# [10]	validation_0-auc:0.84968
# [11]	validation_0-auc:0.84948
# [12]	validation_0-auc:0.84944
# [13]	validation_0-auc:0.84923
# [14]	validation_0-auc:0.84956
# [15]	validation_0-auc:0.85005
# [16]	validation_0-auc:0.85087
# [17]	validation_0-auc:0.85112
# [18]	validation_0-auc:0.85122
# [19]	validation_0-auc:0.85102
# [20]	validation_0-auc:0.85091
# [21]	validation_0-auc:0.85084
# [22]	validation_0-auc:0.85066
# [23]	validation_0-auc:0.85077
# [24]	validation_0-auc:0.85074
# [25]	validation_0-auc:0.85064
# [26]	validation_0-auc:0.85081
# [27]	validation_0-auc:0.85108
# [28]	validation_0-auc:0.85120
# [29]	validation_0-auc:0.85123
# [30]	validation_0-auc:0.85137
# [31]	validation_0-auc:0.85142
# [32]	validation_0-auc:0.85137
# [33]	validation_0-auc:0.85125
# [34]	validation_0-auc:0.85169
# [35]	validation_0-auc:0.85192
# [36]	validation_0-auc:0.85205
# [37]	validation_0-auc:0.85205
# [38]	validation_0-auc:0.85216
# [39]	validation_0-auc:0.85230
# [40]	validation_0-auc:0.85225
# [41]	validation_0-auc:0.85212
# [42]	validation_0-auc:0.85242
# [43]	validation_0-auc:0.85242
# [44]	validation_0-auc:0.85242
# [45]	validation_0-auc:0.85253
# [46]	validation_0-auc:0.85271
# [47]	validation_0-auc:0.85274
# [48]	validation_0-auc:0.85289
# [49]	validation_0-auc:0.85310
# [50]	validation_0-auc:0.85298
# [51]	validation_0-auc:0.85293
# [52]	validation_0-auc:0.85288
# [53]	validation_0-auc:0.85291
# [54]	validation_0-auc:0.85301
# [55]	validation_0-auc:0.85295
# [56]	validation_0-auc:0.85300
# [57]	validation_0-auc:0.85314
# [58]	validation_0-auc:0.85316
# [59]	validation_0-auc:0.85317
# [60]	validation_0-auc:0.85315
# [61]	validation_0-auc:0.85320
# [62]	validation_0-auc:0.85349
# [63]	validation_0-auc:0.85349
# [64]	validation_0-auc:0.85359
# [65]	validation_0-auc:0.85367
# [66]	validation_0-auc:0.85372
# [67]	validation_0-auc:0.85381
# [68]	validation_0-auc:0.85387
# [69]	validation_0-auc:0.85397
# [70]	validation_0-auc:0.85398
# [71]	validation_0-auc:0.85424
# [72]	validation_0-auc:0.85425
# [73]	validation_0-auc:0.85427
# [74]	validation_0-auc:0.85433
# [75]	validation_0-auc:0.85442
# [76]	validation_0-auc:0.85447
# [77]	validation_0-auc:0.85449
# [78]	validation_0-auc:0.85464
# [79]	validation_0-auc:0.85469
# [80]	validation_0-auc:0.85477
# [81]	validation_0-auc:0.85490
# [82]	validation_0-auc:0.85491
# [83]	validation_0-auc:0.85492
# [84]	validation_0-auc:0.85493
# [85]	validation_0-auc:0.85501
# [86]	validation_0-auc:0.85508
# [87]	validation_0-auc:0.85514
# [88]	validation_0-auc:0.85517
# [89]	validation_0-auc:0.85523
# [90]	validation_0-auc:0.85535
# [91]	validation_0-auc:0.85543
# [92]	validation_0-auc:0.85548
# [93]	validation_0-auc:0.85551
# [94]	validation_0-auc:0.85558
# [95]	validation_0-auc:0.85565
# [96]	validation_0-auc:0.85569
# [97]	validation_0-auc:0.85580
# [98]	validation_0-auc:0.85582
# [99]	validation_0-auc:0.85588
# [100]	validation_0-auc:0.85594
# [101]	validation_0-auc:0.85596
# [102]	validation_0-auc:0.85611
# [103]	validation_0-auc:0.85615
# [104]	validation_0-auc:0.85617
# [105]	validation_0-auc:0.85619
# [106]	validation_0-auc:0.85621
# [107]	validation_0-auc:0.85626
# [108]	validation_0-auc:0.85629
# [109]	validation_0-auc:0.85631
# [110]	validation_0-auc:0.85631
# [111]	validation_0-auc:0.85631
# [112]	validation_0-auc:0.85637
# [113]	validation_0-auc:0.85641
# [114]	validation_0-auc:0.85650
# [115]	validation_0-auc:0.85651
# [116]	validation_0-auc:0.85655
# [117]	validation_0-auc:0.85655
# [118]	validation_0-auc:0.85663
# [119]	validation_0-auc:0.85669
# [120]	validation_0-auc:0.85671
# [121]	validation_0-auc:0.85672
# [122]	validation_0-auc:0.85677
# [123]	validation_0-auc:0.85680
# [124]	validation_0-auc:0.85682
# [125]	validation_0-auc:0.85683
# [126]	validation_0-auc:0.85686
# [127]	validation_0-auc:0.85690
# [128]	validation_0-auc:0.85689
# [129]	validation_0-auc:0.85692
# [130]	validation_0-auc:0.85697
# [131]	validation_0-auc:0.85697
# [132]	validation_0-auc:0.85699
# [133]	validation_0-auc:0.85704
# [134]	validation_0-auc:0.85706
# [135]	validation_0-auc:0.85709
# [136]	validation_0-auc:0.85715
# [137]	validation_0-auc:0.85717
# [138]	validation_0-auc:0.85715
# [139]	validation_0-auc:0.85719
# [140]	validation_0-auc:0.85719
# [141]	validation_0-auc:0.85720
# [142]	validation_0-auc:0.85724
# [143]	validation_0-auc:0.85724
# [144]	validation_0-auc:0.85724
# [145]	validation_0-auc:0.85725
# [146]	validation_0-auc:0.85725
# [147]	validation_0-auc:0.85726
# [148]	validation_0-auc:0.85725
# [149]	validation_0-auc:0.85725
# [150]	validation_0-auc:0.85722
# [151]	validation_0-auc:0.85721
# [152]	validation_0-auc:0.85723
# [153]	validation_0-auc:0.85719
# [154]	validation_0-auc:0.85720
# [155]	validation_0-auc:0.85721
# [156]	validation_0-auc:0.85721
# [157]	validation_0-auc:0.85723
# [158]	validation_0-auc:0.85719
# [159]	validation_0-auc:0.85721
# [160]	validation_0-auc:0.85725
# [161]	validation_0-auc:0.85723
# [162]	validation_0-auc:0.85728
# [163]	validation_0-auc:0.85727
# [164]	validation_0-auc:0.85725
# [165]	validation_0-auc:0.85725
# [166]	validation_0-auc:0.85723
# [167]	validation_0-auc:0.85724
# [168]	validation_0-auc:0.85723
# [169]	validation_0-auc:0.85720
# [170]	validation_0-auc:0.85720
# [171]	validation_0-auc:0.85722
# [172]	validation_0-auc:0.85723
# [173]	validation_0-auc:0.85726
# [174]	validation_0-auc:0.85727
# [175]	validation_0-auc:0.85729
# [176]	validation_0-auc:0.85732
# [177]	validation_0-auc:0.85733
# [178]	validation_0-auc:0.85734
# [179]	validation_0-auc:0.85735
# [180]	validation_0-auc:0.85739
# [181]	validation_0-auc:0.85740
# [182]	validation_0-auc:0.85741
# [183]	validation_0-auc:0.85741
# [184]	validation_0-auc:0.85742
# [185]	validation_0-auc:0.85742
# [186]	validation_0-auc:0.85742
# [187]	validation_0-auc:0.85742
# [188]	validation_0-auc:0.85741
# [189]	validation_0-auc:0.85741
# [190]	validation_0-auc:0.85743
# [191]	validation_0-auc:0.85747
# [192]	validation_0-auc:0.85745
# [193]	validation_0-auc:0.85749
# [194]	validation_0-auc:0.85747
# [195]	validation_0-auc:0.85747
# [196]	validation_0-auc:0.85747
# [197]	validation_0-auc:0.85748
# [198]	validation_0-auc:0.85748
# [199]	validation_0-auc:0.85749
# [200]	validation_0-auc:0.85747
# [201]	validation_0-auc:0.85748
# [202]	validation_0-auc:0.85751
# [203]	validation_0-auc:0.85751
# [204]	validation_0-auc:0.85752
# [205]	validation_0-auc:0.85751
# [206]	validation_0-auc:0.85752
# [207]	validation_0-auc:0.85752
# [208]	validation_0-auc:0.85752
# [209]	validation_0-auc:0.85752
# [210]	validation_0-auc:0.85751
# [211]	validation_0-auc:0.85751
# [212]	validation_0-auc:0.85754
# [213]	validation_0-auc:0.85754
# [214]	validation_0-auc:0.85754
# [215]	validation_0-auc:0.85757
# [216]	validation_0-auc:0.85758
# [217]	validation_0-auc:0.85757
# [218]	validation_0-auc:0.85757
# [219]	validation_0-auc:0.85759
# [220]	validation_0-auc:0.85760
# [221]	validation_0-auc:0.85761
# [222]	validation_0-auc:0.85761
# [223]	validation_0-auc:0.85761
# [224]	validation_0-auc:0.85762
# [225]	validation_0-auc:0.85765
# [226]	validation_0-auc:0.85766
# [227]	validation_0-auc:0.85767
# [228]	validation_0-auc:0.85767
# [229]	validation_0-auc:0.85766
# [230]	validation_0-auc:0.85767
# [231]	validation_0-auc:0.85766
# [232]	validation_0-auc:0.85766
# [233]	validation_0-auc:0.85766
# [234]	validation_0-auc:0.85766
# [235]	validation_0-auc:0.85767
# [236]	validation_0-auc:0.85769
# [237]	validation_0-auc:0.85768
# [238]	validation_0-auc:0.85771
# [239]	validation_0-auc:0.85772
# [240]	validation_0-auc:0.85773
# [241]	validation_0-auc:0.85772
# [242]	validation_0-auc:0.85773
# [243]	validation_0-auc:0.85775
# [244]	validation_0-auc:0.85775
# [245]	validation_0-auc:0.85777
# [246]	validation_0-auc:0.85778
# [247]	validation_0-auc:0.85777
# [248]	validation_0-auc:0.85777
# [249]	validation_0-auc:0.85776
# [250]	validation_0-auc:0.85775
# [251]	validation_0-auc:0.85774
# [252]	validation_0-auc:0.85776
# [253]	validation_0-auc:0.85776
# [254]	validation_0-auc:0.85776
# [255]	validation_0-auc:0.85776
# [256]	validation_0-auc:0.85776
# [257]	validation_0-auc:0.85776
# [258]	validation_0-auc:0.85775
# [259]	validation_0-auc:0.85775
# [260]	validation_0-auc:0.85773
# [261]	validation_0-auc:0.85773
# [262]	validation_0-auc:0.85774
# [263]	validation_0-auc:0.85773
# [264]	validation_0-auc:0.85774
# [265]	validation_0-auc:0.85776
# [266]	validation_0-auc:0.85774
# [267]	validation_0-auc:0.85774
# [268]	validation_0-auc:0.85775
# [269]	validation_0-auc:0.85776
# [270]	validation_0-auc:0.85776
# [271]	validation_0-auc:0.85776
# [272]	validation_0-auc:0.85777
# [273]	validation_0-auc:0.85778
# [274]	validation_0-auc:0.85779
# [275]	validation_0-auc:0.85778
# [276]	validation_0-auc:0.85778
# [277]	validation_0-auc:0.85781
# [278]	validation_0-auc:0.85781
# [279]	validation_0-auc:0.85780
# [280]	validation_0-auc:0.85780
# [281]	validation_0-auc:0.85780
# [282]	validation_0-auc:0.85780
# [283]	validation_0-auc:0.85781
# [284]	validation_0-auc:0.85781
# [285]	validation_0-auc:0.85781
# [286]	validation_0-auc:0.85782
# [287]	validation_0-auc:0.85781
# [288]	validation_0-auc:0.85780
# [289]	validation_0-auc:0.85780
# [290]	validation_0-auc:0.85782
# [291]	validation_0-auc:0.85781
# [292]	validation_0-auc:0.85781
# [293]	validation_0-auc:0.85782
# [294]	validation_0-auc:0.85784
# [295]	validation_0-auc:0.85786
# [296]	validation_0-auc:0.85787
# [297]	validation_0-auc:0.85787
# [298]	validation_0-auc:0.85787
# [299]	validation_0-auc:0.85787
# [300]	validation_0-auc:0.85787
# [301]	validation_0-auc:0.85789
# [302]	validation_0-auc:0.85788
# [303]	validation_0-auc:0.85788
# [304]	validation_0-auc:0.85789
# [305]	validation_0-auc:0.85791
# [306]	validation_0-auc:0.85791
# [307]	validation_0-auc:0.85791
# [308]	validation_0-auc:0.85791
# [309]	validation_0-auc:0.85791
# [310]	validation_0-auc:0.85793
# [311]	validation_0-auc:0.85793
# [312]	validation_0-auc:0.85793
# [313]	validation_0-auc:0.85793
# [314]	validation_0-auc:0.85791
# [315]	validation_0-auc:0.85792
# [316]	validation_0-auc:0.85791
# [317]	validation_0-auc:0.85791
# [318]	validation_0-auc:0.85791
# [319]	validation_0-auc:0.85791
# [320]	validation_0-auc:0.85791
# [321]	validation_0-auc:0.85791
# [322]	validation_0-auc:0.85790
# [323]	validation_0-auc:0.85790
# [324]	validation_0-auc:0.85791
# [325]	validation_0-auc:0.85792
# [326]	validation_0-auc:0.85794
# [327]	validation_0-auc:0.85795
# [328]	validation_0-auc:0.85795
# [329]	validation_0-auc:0.85794
# [330]	validation_0-auc:0.85794
# [331]	validation_0-auc:0.85792
# [332]	validation_0-auc:0.85792
# [333]	validation_0-auc:0.85791
# [334]	validation_0-auc:0.85791
# [335]	validation_0-auc:0.85791
# [336]	validation_0-auc:0.85790
# [337]	validation_0-auc:0.85791
# [338]	validation_0-auc:0.85791
# [339]	validation_0-auc:0.85791
# [340]	validation_0-auc:0.85793
# [341]	validation_0-auc:0.85792
# [342]	validation_0-auc:0.85791
# [343]	validation_0-auc:0.85792
# [344]	validation_0-auc:0.85792
# [345]	validation_0-auc:0.85793
# [346]	validation_0-auc:0.85793
# [347]	validation_0-auc:0.85790
# [348]	validation_0-auc:0.85790
# [349]	validation_0-auc:0.85789
# [350]	validation_0-auc:0.85789
# [351]	validation_0-auc:0.85788
# [352]	validation_0-auc:0.85787
# [353]	validation_0-auc:0.85786
# [354]	validation_0-auc:0.85785
# [355]	validation_0-auc:0.85786
# [356]	validation_0-auc:0.85786
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=0.8, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.05, max_delta_step=0, max_depth=5,
#               min_child_weight=5, missing=nan, monotone_constraints='()',
#               n_estimators=500, n_jobs=4, nthread=4, num_parallel_tree=1,
#               random_state=27, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#               seed=27, subsample=0.8, tree_method='exact',
#               validate_parameters=1, verbosity=None)

# %%
gsearch1.best_score_
# Out:
# 0.857535794853251

# %%
gsearch1.best_params_
# Out:
# {'gamma': 0, 'max_depth': 5, 'min_child_weight': 1}

# %% [markdown]
# ## Using oversampling
# This first cell is wrong but I still included it to highlight an error I made at first. Applying oversampling to the validation set will cause us to grossly underestimate the generalization error.

# %%
from xgboost import XGBClassifier

from sklearn.model_selection import RandomizedSearchCV, GridSearchCV

Xs_train, Xs_val, ys_train, ys_val = train_test_split(Xt_smoted, yt_smoted, random_state=123)

estimator = XGBClassifier( learning_rate =0.05, 
                          n_estimators=300, 
                          max_depth=5,
                          min_child_weight=5, 
                          gamma=0, 
                          subsample=0.8, 
                          colsample_bytree=0.8,
                          objective= 'binary:logistic', 
                          nthread=4, 
                          scale_pos_weight=1, 
                          seed=27)

estimator.fit(Xs_train, ys_train,
             eval_set=[(Xs_val, ys_val)],
             eval_metric='auc',
             early_stopping_rounds=30)
# Out:
# [0]	validation_0-auc:0.84291
# [1]	validation_0-auc:0.85778
# [2]	validation_0-auc:0.85822
# [3]	validation_0-auc:0.85799
# [4]	validation_0-auc:0.85792
# [5]	validation_0-auc:0.85832
# [6]	validation_0-auc:0.85908
# [7]	validation_0-auc:0.86190
# [8]	validation_0-auc:0.86240
# [9]	validation_0-auc:0.86586
# [10]	validation_0-auc:0.86605
# [11]	validation_0-auc:0.86702
# [12]	validation_0-auc:0.86742
# [13]	validation_0-auc:0.86816
# [14]	validation_0-auc:0.86964
# [15]	validation_0-auc:0.86908
# [16]	validation_0-auc:0.87335
# [17]	validation_0-auc:0.87382
# [18]	validation_0-auc:0.87446
# [19]	validation_0-auc:0.87482
# [20]	validation_0-auc:0.87563
# [21]	validation_0-auc:0.87573
# [22]	validation_0-auc:0.87644
# [23]	validation_0-auc:0.87840
# [24]	validation_0-auc:0.87845
# [25]	validation_0-auc:0.88037
# [26]	validation_0-auc:0.88014
# [27]	validation_0-auc:0.88047
# [28]	validation_0-auc:0.88147
# [29]	validation_0-auc:0.88211
# [30]	validation_0-auc:0.88231
# [31]	validation_0-auc:0.88377
# [32]	validation_0-auc:0.88363
# [33]	validation_0-auc:0.88458
# [34]	validation_0-auc:0.88431
# [35]	validation_0-auc:0.88641
# [36]	validation_0-auc:0.88688
# [37]	validation_0-auc:0.88774
# [38]	validation_0-auc:0.88814
# [39]	validation_0-auc:0.88840
# [40]	validation_0-auc:0.89003
# [41]	validation_0-auc:0.89054
# [42]	validation_0-auc:0.89135
# [43]	validation_0-auc:0.89177
# [44]	validation_0-auc:0.89275
# [45]	validation_0-auc:0.89315
# [46]	validation_0-auc:0.89304
# [47]	validation_0-auc:0.89418
# [48]	validation_0-auc:0.89431
# [49]	validation_0-auc:0.89472
# [50]	validation_0-auc:0.89515
# [51]	validation_0-auc:0.89566
# [52]	validation_0-auc:0.89601
# [53]	validation_0-auc:0.89609
# [54]	validation_0-auc:0.89625
# [55]	validation_0-auc:0.89667
# [56]	validation_0-auc:0.89693
# [57]	validation_0-auc:0.89817
# [58]	validation_0-auc:0.89929
# [59]	validation_0-auc:0.89983
# [60]	validation_0-auc:0.89989
# [61]	validation_0-auc:0.90039
# [62]	validation_0-auc:0.90080
# [63]	validation_0-auc:0.90111
# [64]	validation_0-auc:0.90250
# [65]	validation_0-auc:0.90262
# [66]	validation_0-auc:0.90394
# [67]	validation_0-auc:0.90424
# [68]	validation_0-auc:0.90465
# [69]	validation_0-auc:0.90541
# [70]	validation_0-auc:0.90623
# [71]	validation_0-auc:0.90646
# [72]	validation_0-auc:0.90688
# [73]	validation_0-auc:0.90694
# [74]	validation_0-auc:0.90769
# [75]	validation_0-auc:0.90841
# [76]	validation_0-auc:0.90853
# [77]	validation_0-auc:0.90923
# [78]	validation_0-auc:0.90943
# [79]	validation_0-auc:0.91034
# [80]	validation_0-auc:0.91062
# [81]	validation_0-auc:0.91135
# [82]	validation_0-auc:0.91220
# [83]	validation_0-auc:0.91234
# [84]	validation_0-auc:0.91267
# [85]	validation_0-auc:0.91319
# [86]	validation_0-auc:0.91356
# [87]	validation_0-auc:0.91370
# [88]	validation_0-auc:0.91416
# [89]	validation_0-auc:0.91446
# [90]	validation_0-auc:0.91534
# [91]	validation_0-auc:0.91555
# [92]	validation_0-auc:0.91573
# [93]	validation_0-auc:0.91612
# [94]	validation_0-auc:0.91866
# [95]	validation_0-auc:0.91883
# [96]	validation_0-auc:0.91976
# [97]	validation_0-auc:0.92007
# [98]	validation_0-auc:0.92003
# [99]	validation_0-auc:0.92122
# [100]	validation_0-auc:0.92174
# [101]	validation_0-auc:0.92191
# [102]	validation_0-auc:0.92203
# [103]	validation_0-auc:0.92256
# [104]	validation_0-auc:0.92338
# [105]	validation_0-auc:0.92391
# [106]	validation_0-auc:0.92415
# [107]	validation_0-auc:0.92430
# [108]	validation_0-auc:0.92463
# [109]	validation_0-auc:0.92503
# [110]	validation_0-auc:0.92590
# [111]	validation_0-auc:0.92645
# [112]	validation_0-auc:0.92656
# [113]	validation_0-auc:0.92680
# [114]	validation_0-auc:0.92692
# [115]	validation_0-auc:0.92714
# [116]	validation_0-auc:0.92737
# [117]	validation_0-auc:0.92748
# [118]	validation_0-auc:0.92788
# [119]	validation_0-auc:0.92828
# [120]	validation_0-auc:0.92873
# [121]	validation_0-auc:0.92944
# [122]	validation_0-auc:0.92953
# [123]	validation_0-auc:0.93011
# [124]	validation_0-auc:0.93064
# [125]	validation_0-auc:0.93062
# [126]	validation_0-auc:0.93084
# [127]	validation_0-auc:0.93092
# [128]	validation_0-auc:0.93097
# [129]	validation_0-auc:0.93160
# [130]	validation_0-auc:0.93210
# [131]	validation_0-auc:0.93225
# [132]	validation_0-auc:0.93265
# [133]	validation_0-auc:0.93275
# [134]	validation_0-auc:0.93301
# [135]	validation_0-auc:0.93342
# [136]	validation_0-auc:0.93430
# [137]	validation_0-auc:0.93439
# [138]	validation_0-auc:0.93451
# [139]	validation_0-auc:0.93477
# [140]	validation_0-auc:0.93487
# [141]	validation_0-auc:0.93502
# [142]	validation_0-auc:0.93585
# [143]	validation_0-auc:0.93612
# [144]	validation_0-auc:0.93644
# [145]	validation_0-auc:0.93666
# [146]	validation_0-auc:0.93675
# [147]	validation_0-auc:0.93680
# [148]	validation_0-auc:0.93720
# [149]	validation_0-auc:0.93730
# [150]	validation_0-auc:0.93742
# [151]	validation_0-auc:0.93761
# [152]	validation_0-auc:0.93801
# [153]	validation_0-auc:0.93811
# [154]	validation_0-auc:0.93815
# [155]	validation_0-auc:0.93828
# [156]	validation_0-auc:0.93835
# [157]	validation_0-auc:0.93841
# [158]	validation_0-auc:0.93860
# [159]	validation_0-auc:0.93863
# [160]	validation_0-auc:0.93878
# [161]	validation_0-auc:0.93893
# [162]	validation_0-auc:0.93898
# [163]	validation_0-auc:0.93928
# [164]	validation_0-auc:0.93933
# [165]	validation_0-auc:0.93970
# [166]	validation_0-auc:0.93978
# [167]	validation_0-auc:0.93982
# [168]	validation_0-auc:0.94068
# [169]	validation_0-auc:0.94078
# [170]	validation_0-auc:0.94085
# [171]	validation_0-auc:0.94086
# [172]	validation_0-auc:0.94089
# [173]	validation_0-auc:0.94092
# [174]	validation_0-auc:0.94117
# [175]	validation_0-auc:0.94124
# [176]	validation_0-auc:0.94222
# [177]	validation_0-auc:0.94239
# [178]	validation_0-auc:0.94243
# [179]	validation_0-auc:0.94290
# [180]	validation_0-auc:0.94300
# [181]	validation_0-auc:0.94304
# [182]	validation_0-auc:0.94312
# [183]	validation_0-auc:0.94325
# [184]	validation_0-auc:0.94335
# [185]	validation_0-auc:0.94341
# [186]	validation_0-auc:0.94360
# [187]	validation_0-auc:0.94363
# [188]	validation_0-auc:0.94366
# [189]	validation_0-auc:0.94368
# [190]	validation_0-auc:0.94378
# [191]	validation_0-auc:0.94396
# [192]	validation_0-auc:0.94413
# [193]	validation_0-auc:0.94464
# [194]	validation_0-auc:0.94466
# [195]	validation_0-auc:0.94473
# [196]	validation_0-auc:0.94510
# [197]	validation_0-auc:0.94543
# [198]	validation_0-auc:0.94555
# [199]	validation_0-auc:0.94586
# [200]	validation_0-auc:0.94590
# [201]	validation_0-auc:0.94608
# [202]	validation_0-auc:0.94625
# [203]	validation_0-auc:0.94628
# [204]	validation_0-auc:0.94632
# [205]	validation_0-auc:0.94633
# [206]	validation_0-auc:0.94636
# [207]	validation_0-auc:0.94638
# [208]	validation_0-auc:0.94649
# [209]	validation_0-auc:0.94672
# [210]	validation_0-auc:0.94679
# [211]	validation_0-auc:0.94682
# [212]	validation_0-auc:0.94686
# [213]	validation_0-auc:0.94705
# [214]	validation_0-auc:0.94754
# [215]	validation_0-auc:0.94759
# [216]	validation_0-auc:0.94776
# [217]	validation_0-auc:0.94791
# [218]	validation_0-auc:0.94793
# [219]	validation_0-auc:0.94847
# [220]	validation_0-auc:0.94848
# [221]	validation_0-auc:0.94853
# [222]	validation_0-auc:0.94852
# [223]	validation_0-auc:0.94864
# [224]	validation_0-auc:0.94884
# [225]	validation_0-auc:0.94895
# [226]	validation_0-auc:0.94901
# [227]	validation_0-auc:0.94906
# [228]	validation_0-auc:0.94906
# [229]	validation_0-auc:0.94914
# [230]	validation_0-auc:0.94916
# [231]	validation_0-auc:0.94935
# [232]	validation_0-auc:0.94938
# [233]	validation_0-auc:0.94979
# [234]	validation_0-auc:0.94996
# [235]	validation_0-auc:0.94996
# [236]	validation_0-auc:0.95005
# [237]	validation_0-auc:0.95013
# [238]	validation_0-auc:0.95014
# [239]	validation_0-auc:0.95024
# [240]	validation_0-auc:0.95034
# [241]	validation_0-auc:0.95044
# [242]	validation_0-auc:0.95049
# [243]	validation_0-auc:0.95053
# [244]	validation_0-auc:0.95059
# [245]	validation_0-auc:0.95059
# [246]	validation_0-auc:0.95079
# [247]	validation_0-auc:0.95084
# [248]	validation_0-auc:0.95106
# [249]	validation_0-auc:0.95110
# [250]	validation_0-auc:0.95129
# [251]	validation_0-auc:0.95130
# [252]	validation_0-auc:0.95134
# [253]	validation_0-auc:0.95137
# [254]	validation_0-auc:0.95138
# [255]	validation_0-auc:0.95138
# [256]	validation_0-auc:0.95149
# [257]	validation_0-auc:0.95165
# [258]	validation_0-auc:0.95176
# [259]	validation_0-auc:0.95176
# [260]	validation_0-auc:0.95184
# [261]	validation_0-auc:0.95211
# [262]	validation_0-auc:0.95221
# [263]	validation_0-auc:0.95222
# [264]	validation_0-auc:0.95236
# [265]	validation_0-auc:0.95249
# [266]	validation_0-auc:0.95251
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [267]	validation_0-auc:0.95269
# [268]	validation_0-auc:0.95282
# [269]	validation_0-auc:0.95300
# [270]	validation_0-auc:0.95303
# [271]	validation_0-auc:0.95312
# [272]	validation_0-auc:0.95314
# [273]	validation_0-auc:0.95317
# [274]	validation_0-auc:0.95317
# [275]	validation_0-auc:0.95325
# [276]	validation_0-auc:0.95328
# [277]	validation_0-auc:0.95338
# [278]	validation_0-auc:0.95339
# [279]	validation_0-auc:0.95353
# [280]	validation_0-auc:0.95353
# [281]	validation_0-auc:0.95356
# [282]	validation_0-auc:0.95378
# [283]	validation_0-auc:0.95382
# [284]	validation_0-auc:0.95387
# [285]	validation_0-auc:0.95403
# [286]	validation_0-auc:0.95448
# [287]	validation_0-auc:0.95469
# [288]	validation_0-auc:0.95480
# [289]	validation_0-auc:0.95486
# [290]	validation_0-auc:0.95499
# [291]	validation_0-auc:0.95503
# [292]	validation_0-auc:0.95510
# [293]	validation_0-auc:0.95515
# [294]	validation_0-auc:0.95517
# [295]	validation_0-auc:0.95536
# [296]	validation_0-auc:0.95539
# [297]	validation_0-auc:0.95554
# [298]	validation_0-auc:0.95565
# [299]	validation_0-auc:0.95574
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=0.8, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.05, max_delta_step=0, max_depth=5,
#               min_child_weight=5, missing=nan, monotone_constraints='()',
#               n_estimators=300, n_jobs=4, nthread=4, num_parallel_tree=1,
#               random_state=27, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#               seed=27, subsample=0.8, tree_method='exact',
#               validate_parameters=1, verbosity=None)

# %%
from xgboost import XGBClassifier
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV

Xs_train, ys_train = smote.fit_resample(X_train, y_train)

# %%
estimator = XGBClassifier( learning_rate =0.2, 
                          n_estimators=300,
                          max_depth=5,
                          min_child_weight=5, 
                          gamma=0, 
                          subsample=0.8, 
                          colsample_bytree=0.8,
                          objective= 'binary:logistic', 
                          nthread=4, 
                          scale_pos_weight=1, 
                          seed=27)

estimator.fit(Xs_train, ys_train,
             eval_set=[(X_val, y_val)],
             eval_metric='auc',
             early_stopping_rounds=50)
# Out:
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [0]	validation_0-auc:0.81396
# [1]	validation_0-auc:0.83304
# [2]	validation_0-auc:0.83546
# [3]	validation_0-auc:0.83714
# [4]	validation_0-auc:0.84048
# [5]	validation_0-auc:0.84062
# [6]	validation_0-auc:0.84127
# [7]	validation_0-auc:0.84141
# [8]	validation_0-auc:0.84231
# [9]	validation_0-auc:0.84273
# [10]	validation_0-auc:0.84263
# [11]	validation_0-auc:0.84284
# [12]	validation_0-auc:0.84307
# [13]	validation_0-auc:0.84308
# [14]	validation_0-auc:0.84527
# [15]	validation_0-auc:0.84530
# [16]	validation_0-auc:0.84499
# [17]	validation_0-auc:0.84491
# [18]	validation_0-auc:0.84520
# [19]	validation_0-auc:0.84541
# [20]	validation_0-auc:0.84552
# [21]	validation_0-auc:0.84622
# [22]	validation_0-auc:0.84644
# [23]	validation_0-auc:0.84612
# [24]	validation_0-auc:0.84590
# [25]	validation_0-auc:0.84564
# [26]	validation_0-auc:0.84553
# [27]	validation_0-auc:0.84561
# [28]	validation_0-auc:0.84560
# [29]	validation_0-auc:0.84566
# [30]	validation_0-auc:0.84535
# [31]	validation_0-auc:0.84554
# [32]	validation_0-auc:0.84592
# [33]	validation_0-auc:0.84633
# [34]	validation_0-auc:0.84650
# [35]	validation_0-auc:0.84720
# [36]	validation_0-auc:0.84722
# [37]	validation_0-auc:0.84749
# [38]	validation_0-auc:0.84737
# [39]	validation_0-auc:0.84745
# [40]	validation_0-auc:0.84728
# [41]	validation_0-auc:0.84728
# [42]	validation_0-auc:0.84743
# [43]	validation_0-auc:0.84704
# [44]	validation_0-auc:0.84707
# [45]	validation_0-auc:0.84746
# [46]	validation_0-auc:0.84737
# [47]	validation_0-auc:0.84741
# [48]	validation_0-auc:0.84777
# [49]	validation_0-auc:0.84782
# [50]	validation_0-auc:0.84772
# [51]	validation_0-auc:0.84775
# [52]	validation_0-auc:0.84770
# [53]	validation_0-auc:0.84764
# [54]	validation_0-auc:0.84758
# [55]	validation_0-auc:0.84769
# [56]	validation_0-auc:0.84787
# [57]	validation_0-auc:0.84789
# [58]	validation_0-auc:0.84758
# [59]	validation_0-auc:0.84750
# [60]	validation_0-auc:0.84716
# [61]	validation_0-auc:0.84736
# [62]	validation_0-auc:0.84730
# [63]	validation_0-auc:0.84709
# [64]	validation_0-auc:0.84714
# [65]	validation_0-auc:0.84712
# [66]	validation_0-auc:0.84746
# [67]	validation_0-auc:0.84763
# [68]	validation_0-auc:0.84763
# [69]	validation_0-auc:0.84751
# [70]	validation_0-auc:0.84765
# [71]	validation_0-auc:0.84767
# [72]	validation_0-auc:0.84768
# [73]	validation_0-auc:0.84767
# [74]	validation_0-auc:0.84762
# [75]	validation_0-auc:0.84765
# [76]	validation_0-auc:0.84779
# [77]	validation_0-auc:0.84777
# [78]	validation_0-auc:0.84776
# [79]	validation_0-auc:0.84766
# [80]	validation_0-auc:0.84772
# [81]	validation_0-auc:0.84767
# [82]	validation_0-auc:0.84771
# [83]	validation_0-auc:0.84772
# [84]	validation_0-auc:0.84772
# [85]	validation_0-auc:0.84788
# [86]	validation_0-auc:0.84786
# [87]	validation_0-auc:0.84790
# [88]	validation_0-auc:0.84770
# [89]	validation_0-auc:0.84759
# [90]	validation_0-auc:0.84757
# [91]	validation_0-auc:0.84764
# [92]	validation_0-auc:0.84760
# [93]	validation_0-auc:0.84761
# [94]	validation_0-auc:0.84774
# [95]	validation_0-auc:0.84773
# [96]	validation_0-auc:0.84777
# [97]	validation_0-auc:0.84779
# [98]	validation_0-auc:0.84765
# [99]	validation_0-auc:0.84727
# [100]	validation_0-auc:0.84722
# [101]	validation_0-auc:0.84713
# [102]	validation_0-auc:0.84715
# [103]	validation_0-auc:0.84708
# [104]	validation_0-auc:0.84717
# [105]	validation_0-auc:0.84713
# [106]	validation_0-auc:0.84719
# [107]	validation_0-auc:0.84686
# [108]	validation_0-auc:0.84680
# [109]	validation_0-auc:0.84687
# [110]	validation_0-auc:0.84696
# [111]	validation_0-auc:0.84702
# [112]	validation_0-auc:0.84702
# [113]	validation_0-auc:0.84707
# [114]	validation_0-auc:0.84676
# [115]	validation_0-auc:0.84696
# [116]	validation_0-auc:0.84704
# [117]	validation_0-auc:0.84700
# [118]	validation_0-auc:0.84679
# [119]	validation_0-auc:0.84706
# [120]	validation_0-auc:0.84707
# [121]	validation_0-auc:0.84702
# [122]	validation_0-auc:0.84702
# [123]	validation_0-auc:0.84706
# [124]	validation_0-auc:0.84710
# [125]	validation_0-auc:0.84701
# [126]	validation_0-auc:0.84709
# [127]	validation_0-auc:0.84674
# [128]	validation_0-auc:0.84679
# [129]	validation_0-auc:0.84680
# [130]	validation_0-auc:0.84672
# [131]	validation_0-auc:0.84674
# [132]	validation_0-auc:0.84685
# [133]	validation_0-auc:0.84668
# [134]	validation_0-auc:0.84667
# [135]	validation_0-auc:0.84664
# [136]	validation_0-auc:0.84667
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=0.8, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.2, max_delta_step=0, max_depth=5,
#               min_child_weight=5, missing=nan, monotone_constraints='()',
#               n_estimators=300, n_jobs=4, nthread=4, num_parallel_tree=1,
#               random_state=27, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#               seed=27, subsample=0.8, tree_method='exact',
#               validate_parameters=1, verbosity=None)

# %%
from sklearn.metrics import confusion_matrix

y_pred = estimator.predict(X_val)
f1_score(y_val, y_pred)
confusion_matrix(y_val, y_pred)
# Out:
# array([[66600, 17066],
#        [ 3572,  8040]])

# %% [markdown]
# ## Conclusion
# Using XGboost we have been able to obtain an AUC score of 0.84 on this classification task.
